# %%
import csv    ##1:bot 2:jg 3:mid 4:top 5:sp
f = open('output.csv', 'w', encoding='utf-8', newline='')
wr = csv.writer(f)
wr.writerow([1723, 2.74, 124.32, 9597, 2])
wr.writerow([701, 2.16, 136.93, 10149, 3])
wr.writerow([3562, 1.76, 131.68, 10572, 2])
wr.writerow([1267, 2.26, 39.33, 7451, 5])
wr.writerow([5364, 2.49, 18.72, 7790, 5])
wr.writerow([1394, 1.85, 126.09, 9816, 4])
wr.writerow([1351, 1.94, 142.73, 10785, 2])
wr.writerow([9373, 1.58, 132.61, 10054, 4])
wr.writerow([3852, 1.77, 135.81, 10405, 2])
wr.writerow([2119, 2.03, 88.74, 9396, 5])
wr.writerow([1995, 2.04, 127.46, 9979, 2])
wr.writerow([431, 2.09, 123.34, 9439, 3])
wr.writerow([1970, 2.18, 90.94, 8706, 4])
wr.writerow([3580, 1.83, 63.80, 9321, 5])
wr.writerow([2799, 1.99, 59.81, 9024, 5])
wr.writerow([736, 1.94, 127.99, 9938, 3])
wr.writerow([2978, 2.15, 101.52, 8947, 3])
wr.writerow([3471, 1.72, 143.18, 10994, 2])
wr.writerow([9221, 1.87, 140.71, 10371, 4])
wr.writerow([1845, 1.6, 141.93, 10255, 2])
wr.writerow([12773, 2.06, 127.80, 10112, 1])
wr.writerow([4793, 1.96, 114.45, 9922, 3])
wr.writerow([10021, 2.1, 145.08, 10551, 1])
wr.writerow([5157, 1.99, 30.61, 7558, 5])
wr.writerow([9236, 2.27, 47.77, 8512, 5])
wr.writerow([2498, 2.19, 108.20, 9880, 2])
wr.writerow([7884, 2.34, 138.78, 10482, 1])
wr.writerow([1866, 1.9, 122.72, 9533, 3])
wr.writerow([7798, 1.52, 142.42, 10832, 2])
wr.writerow([5243, 2.01, 32.23, 7519, 5])
wr.writerow([8227, 1.76, 130.39, 10345, 2])
wr.writerow([2958, 2.2, 61.04, 8929, 5])
wr.writerow([2001, 1.97, 156.99, 10600, 3])
wr.writerow([1698, 1.64, 157.54, 10533, 4])
wr.writerow([2753, 2.59, 15.34, 7439, 5])
wr.writerow([833, 1.99, 118.15, 10037, 4])
wr.writerow([2477, 1.77, 134.34, 9825, 4])
wr.writerow([4014, 2.03, 96.80, 9147, 4])
wr.writerow([1747, 1.8, 128.79, 9782, 4])
wr.writerow([10176, 1.98, 133.88, 10260, 1])
wr.writerow([2930, 1.4, 143.85, 10060, 4])
wr.writerow([1801, 2.29, 98.95, 9437, 5])
wr.writerow([7341, 1.85, 129.70, 9917, 2])
wr.writerow([2114, 1.61, 129.93, 10236, 4])
wr.writerow([1189, 2.33, 101.53, 9385, 3])
wr.writerow([2526, 2.1, 110.82, 10145, 3])
wr.writerow([6664, 1.63, 122.59, 9905, 5])
wr.writerow([1461, 1.94, 122.83, 9148, 4])
wr.writerow([5212, 2.18, 115.56, 9549, 3])
wr.writerow([4373, 2.44, 103.75, 9125, 4])
wr.writerow([2496, 1.97, 112.60, 9810, 3])
wr.writerow([4408, 2.22, 19.76, 7178, 5])
wr.writerow([13372, 2.24, 60.16, 8700, 5])
wr.writerow([2159, 1.49, 140.32, 10396, 4])
wr.writerow([1256, 2.06, 129.53, 9658, 2])
wr.writerow([3146, 2.03, 138.28, 10546, 2])
wr.writerow([5838, 1.99, 39.89, 7690, 5])
wr.writerow([1225])
wr.writerow([])
wr.writerow([])
wr.writerow([])

f.close()
